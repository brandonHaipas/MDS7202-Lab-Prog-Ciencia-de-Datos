# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2025</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Stefano Schiappacasse,Sebastián Tinoco
# - Auxiliares: Melanie Peña, Valentina Rojas
# - Ayudantes: Angelo Muñoz, Valentina Zúñiga

# %% [markdown]
# ### Equipo: **SUPER IMPORTANTE - notebooks sin nombre no serán revisados**
#
# - Felipe Hernández
# - Brandon Peña

# %% [markdown]
# ### **Link de repositorio de GitHub:** [Insertar Enlace](https://)

# %% [markdown]
# ## Reglas:
#
# - **Grupos de 2 personas**
# - Fecha de entrega: 6 días de plazo con descuento de 1 punto por día. Entregas Martes a las 23:59.
# - Instrucciones del lab el viernes a las 16:15 en formato online. Asistencia no es obligatoria, pero se recomienda fuertemente asistir.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Tienen que subir el laboratorio a u-cursos y a su repositorio de github. Labs que no estén en u-cursos no serán revisados. Recuerden que el repositorio también tiene nota.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - Pueden usar cualquier material del curso que estimen conveniente.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2.5 pts)
#
# <p align="center">
#   <img src="https://cdn.thedesigninspiration.com/wp-content/uploads/sites/3/2019/04/macintosh-hdusersbrittanyloefflerdownloadsanig-1.gif" width="350">
# </p>

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 1. Git es un DVCS (Sistema de Control de Versiones Distribuido) de código abierto. Su relación con el control de versiones es que este software permite gestionar distintas versiones de proyectos de código.
# 2. I. Git es un sistema de control de versiones, por otro lado, Github es una plataforma que ofrece servicio a desarrolladores (hosting de repositorios, copilot, etc.).
#    II. Git es de código abierto, es decir, cualquiera puede acceder a su código fuente y contribuir o modificarlo de acuerdo a sus necesidades. Por otro lado, Github es propietario, es decir, no se puede acceder a su código fuente.
#    III. Git es una herramienta de línea de comandos mientras que Github tiene una plataforma web y se basa en interfaces gráficas para su uso.
#
# 3. El `hash`es un string de 40 caracteres hexadecimales generado por la función criptográfica SHA-1 que sirve para identificar de forma única un objeto dentro del modelo de datos de git. Este objeto puede ser un `blob`, un `tree` o un `commit`.
# 4. Como se mencionó anteriormente, los elementos que componen la estructura de datos de git son `blob`, `tree` y `commit`.
# 5. Para crear un repositorio: `git init`. Para hacer seguimiento: `git status` para ver el estado de la rama, `git log` para ver el historial de commits y `git fetch` para traer los últimos cambios en el repositorio remoto comunmente denominado `origin`.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. `git status` genera los mismos resultados que `git log`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 6. Falso, al realizar un merge en `git`, si se encuentran cambios en la misma línea de un mismo archivo de las dos ramas implicadas ocurre un *conflicto*, el cual debe resolverse manualmente para decidir si quedarse con qué cambio quedarse (o ambos).
# 7. Falso, `git pull`se utiliza para traer cambios de un repositorio remoto a un repositorio local, mientras que `git clone` sirve para clonar (copiar desde cero a un repositorio remoto a nuestra máquina local) un repositorio remoto.
# 8. Falso, `git status` muestra información acerca del estado actual del working directory y staging area del repositorio, mientras que `git log` entrega información acerca de los commits históricos que se han realizado al repositorio.
# 9. Verdadero, en `git` es posible eliminar cambios del repositorio local utilizando `git reset`, o bien volver a versiones anteriores de archivos o del proyecto completo (commit) con `git checkout`.
# 10. Falso, `git commit` se utiliza para llevar los cambios del staging area al repositorio local. Para enviar cambios al repositorio remoto se utiliza `git push`.

# %% [markdown]
# Por último, investigue y comente con sus palabras para qué sirven los siguientes comandos:
#
# 11. `git stash` (0.25 puntos) El comando `git stash` permite *esconder* cambios a medias que existen en el *working directory* y en el *staging area* que no se quieran agregar a un *commit* en el momento para subsecuentemente recuperarlos con *git stash pop* o *git stash apply*. Es de gran utilidad para cambiar de ramas sin perder cambios a medias.
# 12. `git reset`. ¿Cuál es la diferencia de este comando con `git revert`?. (0.25 puntos) Git reset mueve el puntero **HEAD** a la  referencia que se le indique dentro de la rama actual, con la flag `--soft` los cambios que hace `git reset`quedan hasta aquí, manteniendo la staging area y el working directory intactos. Ahora, is se usa la flag `--mixed` además de cambiar HEAD, se revierte el commit y se deshacen los cambios en el staging area, pero se mantiene el working directory. Por último, la flag `--hard` cambia el puntero HEAD, deshace los cambios en el staging area y en el working directory. Si además se le da un camino a un archivo, se comporta de forma similar pero afectando solamente a ese archivo. En cambio, `git revert` crea un nuevo commit para deshacer los cambios de un commit anterior, manteniendo el historial de cambios intacto.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (1.5 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/arqlNu8gyJYAAAAC/cat-cat-jumping.gif" width="150">
# </p>

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Vincular el repositorio a su ambiente local ¿Qué comando(s) me permiten hacer esto?
# 4. Crear un archivo `readme.md` con la información que ustedes deseen compartir.
# 5. Realizar `push` con los cambios generados
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/Mezosky)
#
# **Nota: Deben trabajar todos estos puntos desde su ambiente local**
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:[https://github.com/brandonHaipas](https://github.com/brandonHaipas)</code>
#
# <code>Link Presentacion 2: [https://github.com/pipeh](https://github.com/pipeh)</code>

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)
#
# <p align="center">
#   <img src="https://media.tenor.com/YXL-0SK15j4AAAAC/dance-animals.gif" width="300">
# </p>
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (**incluya también los comandos en `Git` ocupados**):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
# ```bash
# git clone https://github.com/MDS7202/lab1.git
# ```

# %% [markdown]
# 2. Descomprima los archivos subidos con la tarea en U-cursos en la carpeta recién clonada de github. Una vez realizado esto, cree un archivo `.gitignore` con el cual omita la carpeta `videos` y los archivos con la extensión `.txt` exceptuando el archivo `171.txt` de la carpeta `texts`. (0.25 pts)

# %% [markdown]
# <code>Para esta pregunta usted deberá adjuntar el .gitignore creado en su repo.</code>
#
# A continuación se entrega el código del `.gitignore`:
#
# ```
# videos
# *.txt
# !171.txt
# ```

# %% [markdown]
# 3. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también cada elemento que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# El proyecto consiste en código que permite emular sonidos de animales. Se estructura de los siguientes elementos:
#
# - `readme.md`: Archivo README que ofrece una breve descripción del proyecto y sirve como presentación para el repositorio.
# - `animales.py`: Archivo de *python* que contiene una función `animales` que recibe un `string` con el nombre de un animal y printea en pantalla una respuesta que representa el sonido de este.
# - `main.py`: Script con el ciclo de ejecución principal del proyecto. Su ejecución solicita al usuario el nombre de un animal y utiliza este como argumento de la ejecución de la función `animales`.

# %% [markdown]
# 4. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Ejecutando `git log --all --graph --decorate`:
#
# - Se detectan las ramas `origin/fix-ifs`, `origin/new_features` y `origin/main`.
# - Se aprecian 4 commits:
#     1. Un commit inicial.
#     2. Un commit que agrega una función, sin especificar cual, pero se asume que es `animales` en `animales.py`.
#     3. Un commit donde se separa el proyecto en modulos, sin especificar cuales.
#     4. Un commit que indica `fix ifs`. Se deduce que deben ser los ifs de la función `animales`, pero no se explica qué clase de errores se están corrigiendo.
# - Se concluye que los commits son poco específicos. Podrían ser más informativos y utilizar convenciones para estandarizar los mensajes.

# %% [markdown]
# 5. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale y explique el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# El error es que los condicionales `if` de la función `animales` se encuentran mal programados, dado que el caso `else` solo se evalúa para la tercera condición. Luego, al utilizar los argumentos `perro` o `gato`, el `ValueError` se gatilla, incluso habiendo printeado correctamente el sonido del animal.
#
# Ejecutando `git blame animales.py`, se determina que el usuario que cometió el error fue `mezosky`.

# %% [markdown]
# 6. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Los commits, en orden de incorporación al repositorio remoto, son los siguientes (obtenidos con `git log --all --graph --decorate`):
#
# 1. `c81ba`: se agrega funcion
# 2. `362fe`: Se separa el proyecto en modulos
# 3. `25543`: fix ifs
#
# Para ver las diferencias entre commits, se ejecutará `git diff` y se mencionarán los hallazgos tras cada ejecución.
#
# `git diff 362fe..c8b1a`
# - Se retira la función `animales` de `main.py` y se añade a `animales.py`, para ser importada desde esta en el ciclo de ejecución principal.
#
# `git diff c8b1a..25543`
# - Se corrige el error de `ifs` en `animales.py` encontrado en la pregunta anterior, reemplazandolos por `elifs` en el archivo `main.py`.

# %% [markdown]
# 7. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Al ejecutar `git merge origin/fix-ifs` ocurre un conlicto en el archivo `main.py` que no permite realizar merge de forma automática. Específicamente, el problema ocurre en que los `ifs` fueron corregidos con `elifs` sobre el código de `main.py` antes de ser modularizado con el archivo `animales.py`.

# %% [markdown]
# 8. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Se crea una nueva rama `fix-conflict` y se trabaja sobre esta con:
#
# ```
# git branch fix-conflict
# git checkout fix-conflict
# ```
# Luego, para solucionar el problema se corrigen lsa lineas 9 y 11 de `animales.py`, reemplazando los `ifs` por `elifs`, tal como se muestra en el código a continuación:
#
# ```
# def animales(input):
#
#     '''
#     Como hace el animalito?
#     '''
#
#     if input.lower() == 'gato':
#         print('miau')
#     elif input.lower() == 'perro':
#         print('guau')
#     elif input.lower() == 'fox':
#         print('https://www.youtube.com/watch?v=jofNR_WkoCE')
#     else:
#         raise ValueError('animal no reconocido :(')
# ```

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <p align="center">
#   <img src="https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif" width="350">
# </p>
